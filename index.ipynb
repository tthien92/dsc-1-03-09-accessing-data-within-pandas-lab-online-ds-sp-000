# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a data set which contains information World cup matches. Let's use the pandas commands learned in the previous lecture to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand and explain some key Pandas methods
# * Access DataFrame data by using the label
# * Perform boolean indexing on both Series and DataFrames
# * Use simple selectors for series
# * Set new Series and DataFrame inputs

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `WorldCupMatches.csv` as a dataframe in Pandas

# %%
import pandas as pd
data = pd.read_csv('WorldCupMatches.csv')
df = pd.DataFrame(data)
df.head()
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the data set.

# %%
df.head(7)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930.0  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
# 6     Yugoslavia              4.0              0.0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
# 5                     9249.0                   1.0                   0.0
# 6                    18306.0                   0.0                   0.0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
# 5         LANGENUS Jean (BEL)    201.0   1095.0                CHI
# 6       WARNKEN Alberto (CHI)    201.0   1092.0                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
df.tail(3)
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4569                   NaN                   NaN     NaN         NaN
# 4570                   NaN                   NaN     NaN         NaN
# 4571                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 4569         NaN      NaN      NaN                NaN                NaN
# 4570         NaN      NaN      NaN                NaN                NaN
# 4571         NaN      NaN      NaN                NaN                NaN

# %% [markdown]
# Get a concise summary of your data using `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
# Year                    852 non-null float64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null float64
# Away Team Goals         852 non-null float64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null float64
# Half-time Away Goals    852 non-null float64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null float64
# MatchID                 852 non-null float64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(8), object(12)
# memory usage: 714.5+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
df.shape
# Out:
# (4572, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting dataframe information

# %% [markdown]
# When looking at the dataframe's `.head()`, you might have noticed that the games are structured chronologically in the dataframe.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
df.iloc[3:6]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
# 5                     9249.0                   1.0                   0.0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3    201.0   1098.0                ROU                PER
# 4    201.0   1085.0                ARG                FRA
# 5    201.0   1095.0                CHI                MEX

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested to print out the "Home Team Name" and the "Away Team Name",

# %%
df.loc[5:10, ['Home Team Name', 'Away Team Name']]
# Out:
#    Home Team Name Away Team Name
# 5           Chile         Mexico
# 6      Yugoslavia        Bolivia
# 7             USA       Paraguay
# 8         Uruguay           Peru
# 9           Chile         France
# 10      Argentina         Mexico

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
df.loc[(df['Stage'] == 'Group 3') & (df['Datetime'].str.contains('1950'))]
# Out:
#       Year              Datetime    Stage           Stadium        City  \
# 56  1950.0  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950.0  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950.0  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden              3.0              2.0          Italy
# 61         Sweden              2.0              2.0       Paraguay
# 65          Italy              2.0              0.0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                   2.0                   1.0
# 61                     7903.0                   2.0                   1.0
# 65                    25811.0                   1.0                   0.0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56    208.0   1219.0                SWE                ITA
# 61    208.0   1228.0                SWE                PAR
# 65    208.0   1218.0                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance colum for the Group 3 games

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
df.loc[(df['Stage'] == 'Group 3'), ['Attendance']]
# Out:
#      Attendance
# 3        2549.0
# 8       57735.0
# 13      70022.0
# 56      36502.0
# 61       7903.0
# 65      25811.0
# 75      20500.0
# 76      25000.0
# 83      34000.0
# 84      26000.0
# 101     34107.0
# 104     15343.0
# 110     15150.0
# 116     38850.0
# 117     30287.0
# 120     13300.0
# 127      2823.0
# 137     10484.0
# 141     12700.0
# 145     14903.0
# 149     11875.0
# 153     18715.0
# 157     10648.0
# 170     47308.0
# 173     29886.0
# 178     51387.0
# 180     25438.0
# 186     58479.0
# 189     24129.0
# 203     50560.0
# 206     52897.0
# 210     56818.0
# 214     66843.0
# 218     50804.0
# 222     49292.0
# 236     55100.0
# 237     23800.0
# 244     53700.0
# 245     13400.0
# 252     53300.0
# 254     28300.0
# 274     32569.0
# 275     40841.0
# 282     34771.0
# 283     41424.0
# 290     35221.0
# 291     42132.0
# 308     95000.0
# 312     23000.0
# 321     32093.0
# 324     15000.0
# 333     37000.0
# 336     32500.0
# 346     43000.0
# 350     44000.0
# 354     44000.0

# %% [markdown]
# Throughout the entire history of the world cup, How many Home games were played by the Netherlands?

# %%
df.loc[(df['Home Team Name'] == 'Netherlands') & (df['Home Team Goals'] > df['Away Team Goals'])]
# Out:
#        Year              Datetime           Stage  \
# 258  1974.0  26 Jun 1974 - 19:30          Group A
# 265  1974.0  03 Jul 1974 - 19:30          Group A
# 277  1978.0  03 Jun 1978 - 16:45          Group 4
# 295  1978.0  14 Jun 1978 - 13:45          Group A
# 302  1978.0  21 Jun 1978 - 13:45          Group A
# 472  1994.0  20 Jun 1994 - 19:30          Group F
# 504  1994.0  04 Jul 1994 - 12:00      Round of 16
# 542  1998.0  20 Jun 1998 - 21:00          Group E
# 569  1998.0  29 Jun 1998 - 21:00      Round of 16
# 574  1998.0  04 Jul 1998 - 16:30   Quarter-finals
# 665  2006.0  16 Jun 2006 - 18:00          Group C
# 716  2010.0  14 Jun 2010 - 13:30          Group E
# 731  2010.0  19 Jun 2010 - 13:30          Group E
# 760  2010.0  28 Jun 2010 - 16:00      Round of 16
# 764  2010.0  02 Jul 2010 - 16:00   Quarter-finals
# 805  2014.0  23 Jun 2014 - 13:00          Group B
# 832  2014.0  29 Jun 2014 - 13:00      Round of 16
# 838  2014.0  29 Jun 2014 - 13:00      Round of 16
#
#                                                Stadium  \
# 258                                        Parkstadion
# 265                                   Westfalenstadion
# 277                                         San Martin
# 295                  Estadio Ol�mpico Chateau Carreras
# 302  El Monumental - Estadio Monumental Antonio Ves...
# 472                                        RFK Stadium
# 504                                        Citrus Bowl
# 542                                    Stade V�lodrome
# 569                                    Stade Municipal
# 574                                    Stade V�lodrome
# 665                           Gottlieb-Daimler-Stadion
# 716                                Soccer City Stadium
# 731                                     Durban Stadium
# 760                                     Durban Stadium
# 764                             Port Elizabeth Stadium
# 805                                 Arena de Sao Paulo
# 832                                   Estadio Castelao
# 838                                   Estadio Castelao
#
#                                    City Home Team Name  Home Team Goals  \
# 258                      Gelsenkirchen     Netherlands              4.0
# 265                           Dortmund     Netherlands              2.0
# 277                            Mendoza     Netherlands              3.0
# 295                            Cordoba     Netherlands              5.0
# 302                       Buenos Aires     Netherlands              2.0
# 472                      Washington Dc     Netherlands              2.0
# 504                            Orlando     Netherlands              2.0
# 542                         Marseilles     Netherlands              5.0
# 569                           Toulouse     Netherlands              2.0
# 574                         Marseilles     Netherlands              2.0
# 665                          Stuttgart     Netherlands              2.0
# 716                       Johannesburg     Netherlands              2.0
# 731                             Durban     Netherlands              1.0
# 760                             Durban     Netherlands              2.0
# 764  Nelson Mandela Bay/Port Elizabeth     Netherlands              2.0
# 805                          Sao Paulo     Netherlands              2.0
# 832                          Fortaleza     Netherlands              2.0
# 838                          Fortaleza     Netherlands              2.0
#
#      Away Team Goals           Away Team Name Win conditions  Attendance  \
# 258              0.0                Argentina                    56548.0
# 265              0.0                   Brazil                    53700.0
# 277              0.0                  IR Iran                    33431.0
# 295              1.0                  Austria                    25050.0
# 302              1.0                    Italy                    67433.0
# 472              1.0             Saudi Arabia                    50535.0
# 504              0.0  rn">Republic of Ireland                    61355.0
# 542              0.0           Korea Republic                    55000.0
# 569              1.0               Yugoslavia                    33500.0
# 574              1.0                Argentina                    55000.0
# 665              1.0            C�te d'Ivoire                    52000.0
# 716              0.0                  Denmark                    83465.0
# 731              0.0                    Japan                    62010.0
# 760              1.0                 Slovakia                    61962.0
# 764              1.0                   Brazil                    40186.0
# 805              0.0                    Chile                    62996.0
# 832              1.0                   Mexico                    58817.0
# 838              1.0                   Mexico                    58817.0
#
#      Half-time Home Goals  Half-time Away Goals  \
# 258                   2.0                   0.0
# 265                   0.0                   0.0
# 277                   1.0                   0.0
# 295                   3.0                   0.0
# 302                   0.0                   1.0
# 472                   0.0                   1.0
# 504                   2.0                   0.0
# 542                   2.0                   0.0
# 569                   1.0                   0.0
# 574                   1.0                   1.0
# 665                   2.0                   1.0
# 716                   0.0                   0.0
# 731                   0.0                   0.0
# 760                   1.0                   0.0
# 764                   0.0                   1.0
# 805                   0.0                   0.0
# 832                   0.0                   0.0
# 838                   0.0                   0.0
#
#                               Referee                     Assistant 1  \
# 258                DAVIDSON Bob (SCO)          TSCHENSCHER Kurt (GER)
# 265            TSCHENSCHER Kurt (GER)              DAVIDSON Bob (SCO)
# 277  GONZALEZ ARCHUNDIA Alfonso (MEX)              WURTZ Robert (FRA)
# 295                 GORDON John (SCO)  ITHURRALDE Arturo Andres (ARG)
# 302              MARTINEZ Angel (ESP)            PESTARINO Luis (ARG)
# 472            DIAZ VEGA Manuel (ESP)           IVANOV Valentin (RUS)
# 504             MIKKELSEN Peter (DEN)            DUNSTER Gordon (AUS)
# 542              WOJCIK Ryszard (POL)           POCIEGIEL Jacek (POL)
# 569    GARCIA ARANDA Jose Maria (ESP)            RAUSIS Laurent (SUI)
# 574        BRIZIO CARTER Arturo (MEX)               POWELL Owen (JAM)
# 665                  RUIZ Oscar (COL)           TAMAYO Fernando (ECU)
# 716             St�phane LANNOY (FRA)             DANSAULT Eric (FRA)
# 731             BALDASSI Hector (ARG)             CASAS Ricardo (ARG)
# 760    Alberto UNDIANO MALLENCO (ESP)           MARTINEZ Fermin (ESP)
# 764            NISHIMURA Yuichi (JPN)               SAGARA Toru (JPN)
# 805              Bakary GASSAMA (GAM)        MENKOUANDE Evarist (CMR)
# 832               PROENCA Pedro (POR)           MIRANDA Bertino (POR)
# 838               PROENCA Pedro (POR)           MIRANDA Bertino (POR)
#
#                      Assistant 2     RoundID      MatchID Home Team Initials  \
# 258          KAZAKOV Pavel (URS)       263.0       1948.0                NED
# 265         SUPPIAH George (SIN)       263.0       1983.0                NED
# 277        COMESANA Miguel (ARG)       278.0       2388.0                NED
# 295           BOUZO Farouk (SYR)       279.0       2220.0                NED
# 302  OROZCO GUERRERO Cesar (PER)       279.0       2391.0                NED
# 472          MARTON Sandor (HUN)       337.0       3058.0                NED
# 504        BRAZZALE Eugene (AUS)       338.0       3089.0                NED
# 542           DUPANOV Yuri (BLR)      1014.0       8749.0                NED
# 569     GRIGORESCU Nicolae (ROU)      1024.0       8778.0                NED
# 574       SALINAS Reynaldo (HON)      1025.0       8784.0                NED
# 665             NAVIA Jose (COL)  97410100.0   97410022.0                NED
# 716            UGO Laurent (FRA)    249722.0  300061478.0                NED
# 731         MAIDANA Hernan (ARG)    249722.0  300111117.0                NED
# 760             YUSTE Juan (ESP)    249717.0  300111113.0                NED
# 764         JEONG Hae Sang (KOR)    249718.0  300061507.0                NED
# 805       KABANDA Felicien (RWA)    255931.0  300186470.0                NED
# 832             TRIGO Jose (POR)    255951.0  300186508.0                NED
# 838             TRIGO Jose (POR)    255951.0  300186508.0                NED
#
#     Away Team Initials
# 258                ARG
# 265                BRA
# 277                IRN
# 295                AUT
# 302                ITA
# 472                KSA
# 504                IRL
# 542                KOR
# 569                YUG
# 574                ARG
# 665                CIV
# 716                DEN
# 731                JPN
# 760                SVK
# 764                BRA
# 805                CHI
# 832                MEX
# 838                MEX

# %% [markdown]
# How many games were playes by the Netherlands in total?

# %%
total_games = df.loc[df['Home Team Name'] == 'Netherlands']
len(total_games)
# Out:
# 32

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 world cup.

# %%
total_US_games = df.loc[(df['Home Team Name'] == 'USA') & (df['Datetime'].str.contains('2014'))]
total_US_games
# Out:
#        Year              Datetime    Stage           Stadium     City  \
# 803  2014.0  22 Jun 2014 - 18:00   Group G    Arena Amazonia  Manaus
# 816  2014.0  26 Jun 2014 - 13:00   Group G  Arena Pernambuco  Recife
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 803            USA              2.0              2.0       Portugal
# 816            USA              0.0              1.0        Germany
#
#     Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 803                    40123.0                   0.0                   1.0
# 816                    41876.0                   0.0                   0.0
#
#                    Referee                  Assistant 1  \
# 803    PITANA Nestor (ARG)         MAIDANA Hernan (ARG)
# 816  Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
#
#                   Assistant 2   RoundID      MatchID Home Team Initials  \
# 803  BELATTI Juan Pablo (ARG)  255931.0  300186483.0                USA
# 816  KOCHKAROV Bakhadyr (KGZ)  255931.0  300186469.0                USA
#
#     Away Team Initials
# 803                POR
# 816                GER

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 world cup.

# %% [markdown]
# Hint 1: as a first step, create a new data set that only contain games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
df.Datetime = pd.to_datetime(df.Datetime, format='%m/%d/%Y')
only_year = df.loc[df.Datetime.dt.year == 1986]
only_names = only_year['Home Team Name']
only_names.unique()
# Out:
# array(['Bulgaria', 'Canada', 'Spain', 'Soviet Union', 'Argentina',
#        'Morocco', 'Algeria', 'Belgium', 'Portugal', 'Paraguay',
#        'Scotland', 'Uruguay', 'Italy', 'France', 'Korea Republic',
#        'Hungary', 'Brazil', 'England', 'Northern Ireland', 'Mexico',
#        'Poland', 'Iraq', 'Denmark', 'Germany FR'], dtype=object)

# %% [markdown]
# In the world cup history, how matches had more than 5 goals in total?

# %%
five_goals = df.loc[(df['Home Team Goals'] + df['Away Team Goals'] >=5)]
five_goals
# Out:
#        Year            Datetime                  Stage  \
# 0    1930.0 1930-07-13 15:00:00                Group 1
# 10   1930.0 1930-07-19 15:00:00                Group 1
# 15   1930.0 1930-07-26 14:45:00            Semi-finals
# 16   1930.0 1930-07-27 14:45:00            Semi-finals
# 17   1930.0 1930-07-30 14:15:00                  Final
# 18   1934.0 1934-05-27 16:30:00      Preliminary round
# 19   1934.0 1934-05-27 16:30:00      Preliminary round
# 20   1934.0 1934-05-27 16:30:00      Preliminary round
# 21   1934.0 1934-05-27 16:30:00      Preliminary round
# 22   1934.0 1934-05-27 16:30:00      Preliminary round
# 24   1934.0 1934-05-27 16:30:00      Preliminary round
# 26   1934.0 1934-05-31 16:30:00         Quarter-finals
# 33   1934.0 1934-06-07 18:00:00  Match for third place
# 36   1938.0 1938-06-05 17:00:00            First round
# 38   1938.0 1938-06-05 17:00:00            First round
# 40   1938.0 1938-06-05 17:30:00            First round
# 43   1938.0 1938-06-09 18:00:00            First round
# 46   1938.0 1938-06-12 17:00:00         Quarter-finals
# 49   1938.0 1938-06-16 18:00:00            Semi-finals
# 51   1938.0 1938-06-19 17:00:00  Match for third place
# 52   1938.0 1938-06-19 17:00:00                  Final
# 56   1950.0 1950-06-25 15:00:00                Group 3
# 59   1950.0 1950-06-28 15:00:00                Group 1
# 66   1950.0 1950-07-02 15:00:00                Group 4
# 68   1950.0 1950-07-02 15:00:00                Group 2
# 70   1950.0 1950-07-09 15:00:00                Group 6
# 71   1950.0 1950-07-13 15:00:00                Group 6
# 72   1950.0 1950-07-13 15:00:00                Group 6
# 77   1954.0 1954-06-16 18:00:00                Group 1
# 79   1954.0 1954-06-17 18:00:00                Group 2
# ..      ...                 ...                    ...
# 554  1998.0 1998-06-24 21:00:00                Group D
# 565  1998.0 1998-06-27 21:00:00            Round of 16
# 567  1998.0 1998-06-28 21:00:00            Round of 16
# 573  1998.0 1998-07-03 21:00:00         Quarter-finals
# 583  2002.0 2002-06-01 20:30:00                Group E
# 595  2002.0 2002-06-05 18:00:00                Group D
# 613  2002.0 2002-06-11 15:30:00                Group A
# 619  2002.0 2002-06-12 20:30:00                Group B
# 620  2002.0 2002-06-13 15:30:00                Group C
# 627  2002.0 2002-06-14 15:30:00                Group H
# 642  2002.0 2002-06-29 20:00:00            Third place
# 644  2006.0 2006-06-09 18:00:00                Group A
# 664  2006.0 2006-06-16 15:00:00                Group C
# 683  2006.0 2006-06-21 21:00:00                Group C
# 686  2006.0 2006-06-22 21:00:00                Group F
# 725  2010.0 2010-06-17 13:30:00                Group B
# 737  2010.0 2010-06-21 13:30:00                Group G
# 748  2010.0 2010-06-24 16:00:00                Group F
# 758  2010.0 2010-06-27 16:00:00            Round of 16
# 768  2010.0 2010-07-06 20:30:00            Semi-finals
# 770  2010.0 2010-07-10 20:30:00  Match for third place
# 774  2014.0 2014-06-13 16:00:00                Group B
# 789  2014.0 2014-06-18 13:00:00                Group B
# 796  2014.0 2014-06-20 16:00:00                Group E
# 802  2014.0 2014-06-22 16:00:00                Group H
# 806  2014.0 2014-06-23 17:00:00                Group A
# 810  2014.0 2014-06-24 16:00:00                Group C
# 812  2014.0 2014-06-25 13:00:00                Group F
# 826  2014.0 2014-07-08 17:00:00            Semi-finals
# 848  2014.0 2014-07-08 17:00:00            Semi-finals
#
#                                        Stadium  \
# 0                                      Pocitos
# 10                          Estadio Centenario
# 15                          Estadio Centenario
# 16                          Estadio Centenario
# 17                          Estadio Centenario
# 18                     Stadio Benito Mussolini
# 19                           Giorgio Ascarelli
# 20                                    San Siro
# 21                                   Littorale
# 22                              Giovanni Berta
# 24                               Nazionale PNF
# 26                     Stadio Benito Mussolini
# 33                           Giorgio Ascarelli
# 36                        Velodrome Municipale
# 38                             Stade Municipal
# 40                          Stade de la Meinau
# 43                            Parc des Princes
# 46                                 Fort Carree
# 49                            Parc des Princes
# 51                       Stade du Parc Lescure
# 52                             Stade Olympique
# 56                                    Pacaembu
# 59                                  Eucaliptos
# 66                               Independencia
# 68                              Ilha do Retiro
# 70   Maracan� - Est�dio Jornalista M�rio Filho
# 71   Maracan� - Est�dio Jornalista M�rio Filho
# 72                                    Pacaembu
# 77                                  Charmilles
# 79                            Wankdorf Stadium
# ..                                         ...
# 554                       Stade Felix Bollaert
# 565                           Parc des Princes
# 567                            Stade de France
# 573                               La Beaujoire
# 583                               Sapporo Dome
# 595                    Suwon World Cup Stadium
# 613                    Suwon World Cup Stadium
# 619                  Daejeon World Cup Stadium
# 620                    Suwon World Cup Stadium
# 627                     Shizuoka Stadium Ecopa
# 642                    Daegu World Cup Stadium
# 644             FIFA World Cup Stadium, Munich
# 664      FIFA World Cup Stadium, Gelsenkirchen
# 683             FIFA World Cup Stadium, Munich
# 686           FIFA World Cup Stadium, Dortmund
# 725                        Soccer City Stadium
# 737                          Cape Town Stadium
# 748                         Ellis Park Stadium
# 758                         Free State Stadium
# 768                          Cape Town Stadium
# 770                     Port Elizabeth Stadium
# 774                           Arena Fonte Nova
# 789                          Estadio Beira-Rio
# 796                           Arena Fonte Nova
# 802                          Estadio Beira-Rio
# 806                           Estadio Nacional
# 810                             Arena Pantanal
# 812                          Estadio Beira-Rio
# 826                           Estadio Mineirao
# 848                           Estadio Mineirao
#
#                                    City  Home Team Name  Home Team Goals  \
# 0                           Montevideo           France              4.0
# 10                          Montevideo        Argentina              6.0
# 15                          Montevideo        Argentina              6.0
# 16                          Montevideo          Uruguay              6.0
# 17                          Montevideo          Uruguay              4.0
# 18                               Turin          Austria              3.0
# 19                              Naples          Hungary              4.0
# 20                               Milan      Switzerland              3.0
# 21                             Bologna           Sweden              3.0
# 22                            Florence          Germany              5.0
# 24                                Rome            Italy              7.0
# 26                               Turin   Czechoslovakia              3.0
# 33                              Naples          Germany              3.0
# 36                               Reims          Hungary              6.0
# 38                            Toulouse             Cuba              3.0
# 40                          Strasbourg           Brazil              6.0
# 43                               Paris      Switzerland              4.0
# 46                             Antibes           Sweden              8.0
# 49                               Paris          Hungary              5.0
# 51                            Bordeaux           Brazil              4.0
# 52                            Colombes            Italy              4.0
# 56                           Sao Paulo           Sweden              3.0
# 59                        Porto Alegre       Yugoslavia              4.0
# 66                      Belo Horizonte          Uruguay              8.0
# 68                              Recife            Chile              5.0
# 70                      Rio De Janeiro           Brazil              7.0
# 71                      Rio De Janeiro           Brazil              6.0
# 72                           Sao Paulo          Uruguay              3.0
# 77                              Geneva           Brazil              5.0
# 79                               Berne       Germany FR              4.0
# ..                                  ...             ...              ...
# 554                               Lens            Spain              6.0
# 565                              Paris           Brazil              4.0
# 567                        Saint-Denis          Nigeria              1.0
# 573                             Nantes           Brazil              3.0
# 583                            Sapporo          Germany              8.0
# 595                              Suwon              USA              3.0
# 613                              Suwon          Senegal              3.0
# 619                            Daejeon     South Africa              2.0
# 620                              Suwon       Costa Rica              2.0
# 627                           Shizuoka          Belgium              3.0
# 642                              Daegu   Korea Republic              2.0
# 644                             Munich          Germany              4.0
# 664                      Gelsenkirchen        Argentina              6.0
# 683                             Munich    C�te d'Ivoire              3.0
# 686                           Dortmund            Japan              1.0
# 725                       Johannesburg        Argentina              4.0
# 737                          Cape Town         Portugal              7.0
# 748                       Johannesburg         Slovakia              3.0
# 758              Mangaung/Bloemfontein          Germany              4.0
# 768                          Cape Town          Uruguay              2.0
# 770  Nelson Mandela Bay/Port Elizabeth          Uruguay              2.0
# 774                           Salvador            Spain              1.0
# 789                       Porto Alegre        Australia              2.0
# 796                           Salvador      Switzerland              2.0
# 802                       Porto Alegre   Korea Republic              2.0
# 806                           Brasilia         Cameroon              1.0
# 810                             Cuiaba            Japan              1.0
# 812                       Porto Alegre          Nigeria              2.0
# 826                     Belo Horizonte           Brazil              1.0
# 848                     Belo Horizonte           Brazil              1.0
#
#      Away Team Goals             Away Team Name  \
# 0                1.0                     Mexico
# 10               3.0                     Mexico
# 15               1.0                        USA
# 16               1.0                 Yugoslavia
# 17               2.0                  Argentina
# 18               2.0                     France
# 19               2.0                      Egypt
# 20               2.0                Netherlands
# 21               2.0                  Argentina
# 22               2.0                    Belgium
# 24               1.0                        USA
# 26               2.0                Switzerland
# 33               2.0                    Austria
# 36               0.0          Dutch East Indies
# 38               3.0                    Romania
# 40               5.0                     Poland
# 43               2.0                    Germany
# 46               0.0                       Cuba
# 49               1.0                     Sweden
# 51               2.0                     Sweden
# 52               2.0                    Hungary
# 56               2.0                      Italy
# 59               1.0                     Mexico
# 66               0.0                    Bolivia
# 68               2.0                        USA
# 70               1.0                     Sweden
# 71               1.0                      Spain
# 72               2.0                     Sweden
# 77               0.0                     Mexico
# 79               1.0                     Turkey
# ..               ...                        ...
# 554              1.0                   Bulgaria
# 565              1.0                      Chile
# 567              4.0                    Denmark
# 573              2.0                    Denmark
# 583              0.0               Saudi Arabia
# 595              2.0                   Portugal
# 613              3.0                    Uruguay
# 619              3.0                      Spain
# 620              5.0                     Brazil
# 627              2.0                     Russia
# 642              3.0                     Turkey
# 644              2.0                 Costa Rica
# 664              0.0  rn">Serbia and Montenegro
# 683              2.0  rn">Serbia and Montenegro
# 686              4.0                     Brazil
# 725              1.0             Korea Republic
# 737              0.0                  Korea DPR
# 748              2.0                      Italy
# 758              1.0                    England
# 768              3.0                Netherlands
# 770              3.0                    Germany
# 774              5.0                Netherlands
# 789              3.0                Netherlands
# 796              5.0                     France
# 802              4.0                    Algeria
# 806              4.0                     Brazil
# 810              4.0                   Colombia
# 812              3.0                  Argentina
# 826              7.0                    Germany
# 848              7.0                    Germany
#
#                     Win conditions  Attendance  Half-time Home Goals  \
# 0                                       4444.0                   3.0
# 10                                     42100.0                   3.0
# 15                                     72886.0                   1.0
# 16                                     79867.0                   3.0
# 17                                     68346.0                   1.0
# 18   Austria win after extra time      16000.0                   0.0
# 19                                      9000.0                   2.0
# 20                                     33000.0                   2.0
# 21                                     14000.0                   1.0
# 22                                      8000.0                   1.0
# 24                                     25000.0                   3.0
# 26                                     12000.0                   1.0
# 33                                      7000.0                   3.0
# 36                                      9000.0                   4.0
# 38                                      7000.0                   0.0
# 40    Brazil win after extra time      13452.0                   0.0
# 43                                     20025.0                   1.0
# 46                                      7000.0                   4.0
# 49                                     20000.0                   3.0
# 51                                     12000.0                   1.0
# 52                                     45000.0                   3.0
# 56                                     36502.0                   2.0
# 59                                     11078.0                   2.0
# 66                                      5284.0                   4.0
# 68                                      8501.0                   2.0
# 70                                    138886.0                   3.0
# 71                                    152772.0                   3.0
# 72                                      7987.0                   1.0
# 77                                     13470.0                   4.0
# 79                                     28000.0                   1.0
# ..                             ...         ...                   ...
# 554                                    38100.0                   2.0
# 565                                    45500.0                   3.0
# 567                                    77000.0                   0.0
# 573                                    35500.0                   2.0
# 583                                    32218.0                   4.0
# 595                                    37306.0                   3.0
# 613                                    33681.0                   3.0
# 619                                    31024.0                   1.0
# 620                                    38524.0                   1.0
# 627                                    46640.0                   1.0
# 642                                    63483.0                   1.0
# 644                                    66000.0                   2.0
# 664                                    52000.0                   3.0
# 683                                    66000.0                   1.0
# 686                                    65000.0                   1.0
# 725                                    82174.0                   2.0
# 737                                    63644.0                   1.0
# 748                                    53412.0                   1.0
# 758                                    40510.0                   2.0
# 768                                    62479.0                   1.0
# 770                                    36254.0                   1.0
# 774                                    48173.0                   1.0
# 789                                    42877.0                   1.0
# 796                                    51003.0                   0.0
# 802                                    42732.0                   0.0
# 806                                    69112.0                   1.0
# 810                                    40340.0                   1.0
# 812                                    43285.0                   1.0
# 826                                    58141.0                   0.0
# 848                                    58141.0                   0.0
#
#      Half-time Away Goals                     Referee  \
# 0                     0.0      LOMBARDI Domingo (URU)
# 10                    1.0        SAUCEDO Ulises (BOL)
# 15                    0.0         LANGENUS Jean (BEL)
# 16                    1.0         REGO Gilberto (BRA)
# 17                    2.0         LANGENUS Jean (BEL)
# 18                    0.0  VAN MOORSEL Johannes (NED)
# 19                    2.0    BARLASSINA Rinaldo (ITA)
# 20                    1.0           EKLIND Ivan (SWE)
# 21                    1.0           BRAUN Eugen (AUT)
# 22                    2.0      MATTEA Francesco (ITA)
# 24                    0.0           MERCET Rene (SUI)
# 26                    1.0         BERANEK Alois (AUT)
# 33                    1.0        CARRARO Albino (ITA)
# 36                    0.0          CONRIE Roger (FRA)
# 38                    0.0       SCARPI Giuseppe (ITA)
# 40                    0.0           EKLIND Ivan (SWE)
# 43                    2.0           EKLIND Ivan (SWE)
# 46                    0.0          KRIST Gustav (TCH)
# 49                    1.0       LECLERCQ Lucien (FRA)
# 51                    2.0         LANGENUS Jean (BEL)
# 52                    1.0    CAPDEVILLE Georges (FRA)
# 56                    1.0             LUTZ Jean (SUI)
# 59                    0.0        LEAFE Reginald (ENG)
# 66                    0.0         READER George (ENG)
# 68                    0.0        GARDELLI Mario (BRA)
# 70                    0.0          ELLIS Arthur (ENG)
# 71                    0.0        LEAFE Reginald (ENG)
# 72                    2.0      GALEATI Giovanni (ITA)
# 77                    0.0         WYSSLING Paul (SUI)
# 79                    1.0  DA COSTA VIEIRA Jose (POR)
# ..                    ...                         ...
# 554                   0.0    VAN DER ENDE Mario (NED)
# 565                   0.0            BATTA Marc (FRA)
# 567                   2.0             MEIER Urs (SUI)
# 573                   1.0     EL GHANDOUR Gamal (EGY)
# 583                   0.0         AQUINO Ubaldo (PAR)
# 595                   1.0          MORENO Byron (ECU)
# 613                   0.0          WEGEREEF Jan (NED)
# 619                   2.0             MANE Saad (KUW)
# 620                   3.0     EL GHANDOUR Gamal (EGY)
# 627                   0.0    NIELSEN Kim Milton (DEN)
# 642                   3.0             MANE Saad (KUW)
# 644                   1.0      ELIZONDO Horacio (ARG)
# 664                   0.0       ROSETTI Roberto (ITA)
# 683                   2.0       RODRIGUEZ Marco (MEX)
# 686                   1.0           POULAT Eric (FRA)
# 725                   1.0    DE BLEECKERE Frank (BEL)
# 737                   0.0            POZO Pablo (CHI)
# 748                   0.0           WEBB Howard (ENG)
# 758                   1.0       LARRIONDA Jorge (URU)
# 768                   1.0       Ravshan IRMATOV (UZB)
# 770                   1.0      ARCHUNDIA Benito (MEX)
# 774                   1.0        Nicola RIZZOLI (ITA)
# 789                   1.0       HAIMOUDI Djamel (ALG)
# 796                   3.0         Bj�rn KUIPERS (NED)
# 802                   3.0         ROLDAN Wilmar (COL)
# 806                   2.0        ERIKSSON Jonas (SWE)
# 810                   1.0         PROENCA Pedro (POR)
# 812                   2.0        Nicola RIZZOLI (ITA)
# 826                   5.0       RODRIGUEZ Marco (MEX)
# 848                   5.0       RODRIGUEZ Marco (MEX)
#
#                     Assistant 1                    Assistant 2     RoundID  \
# 0         CRISTOPHE Henry (BEL)            REGO Gilberto (BRA)       201.0
# 10       ALONSO Gualberto (URU)     RADULESCU Constantin (ROU)       201.0
# 15         VALLEJO Gaspar (MEX)          WARNKEN Alberto (CHI)       202.0
# 16         SAUCEDO Ulises (BOL)            BALWAY Thomas (FRA)       202.0
# 17         SAUCEDO Ulises (BOL)          CRISTOPHE Henry (BEL)       405.0
# 18        CAIRONI Camillo (ITA)              BAERT Louis (BEL)       204.0
# 19       DATTILO Generoso (ITA)             SASSI Otello (ITA)       204.0
# 20          BERANEK Alois (AUT)      BONIVENTO Ferruccio (ITA)       204.0
# 21         CARRARO Albino (ITA)        TURBIANI Giuseppe (ITA)       204.0
# 22   MELANDRI Ermenegildo (ITA)            BAERT Jacques (FRA)       204.0
# 24         ESCARTIN Pedro (ESP)          ZENISEK Bohumil (TCH)       204.0
# 26        MOHAMED Youssuf (EGY)            BAERT Jacques (FRA)       418.0
# 33        CAIRONI Camillo (ITA)           ESCARTIN Pedro (ESP)      3491.0
# 36    DE LA SALLE Charles (FRA)         WEINGARTNER Karl (AUT)       206.0
# 38     VALPREDE Ferdinand (FRA)              MERKCX Jean (FRA)       206.0
# 40         POISSANT Louis (FRA)      KISSENBERGER Ernest (FRA)       206.0
# 43            BAERT Louis (BEL)     VAN MOORSEL Johannes (NED)       206.0
# 46       WEINGARTNER Karl (AUT)              SDEZ Victor (FRA)       429.0
# 49   VAN MOORSEL Johannes (NED)          SCARPI Giuseppe (ITA)      3489.0
# 51               OLIVE D. (FRA)       VALPREDE Ferdinand (FRA)      3488.0
# 52         WUETHRICH Hans (SUI)             KRIST Gustav (TCH)      3487.0
# 56          BERANEK Alois (AUT)            TEJADA Carlos (MEX)       208.0
# 59         DAHLNER Gunnar (SWE)       VAN DER MEER Karel (NED)       208.0
# 66            VIANA Mario (BRA)              LEMESIC Leo (YUG)       208.0
# 68      HEYEN Mario Ruben (PAR)          ALVAREZ Alfredo (BOL)       208.0
# 70       GARCIA Prudencio (USA)      DE LA SALLE Charles (FRA)       209.0
# 71        MITCHELL George (SCO)     DA COSTA VIEIRA Jose (POR)       209.0
# 72          BERANEK Alois (AUT)       DE NICOLA Cayetano (PAR)       209.0
# 77     SCHONHOLZER Ernest (SUI)     DA COSTA VIEIRA Jose (POR)       211.0
# 79           ZSOLT Istvan (HUN)          MERLOTTI Armand (SUI)       211.0
# ..                          ...                            ...         ...
# 554    GRIGORESCU Nicolae (ROU)            ROSSI Claudio (ARG)      1014.0
# 565    POUDEVIGNE Jacques (FRA)              POWELL Owen (JAM)      1024.0
# 567    GHADANFARI Hussain (KUW)  TRESACO GRACIA Fernando (ESP)      1024.0
# 573        MANSRI Mohamed (TUN)            DANTE Dramane (MLI)      1025.0
# 583     GIACOMUZZI Miguel (PAR)        RAGOONATH Michael (TRI)  43950100.0
# 595          FIERRO Bomer (ECU)           HASSOUNEH Awni (JOR)  43950100.0
# 613             POOL Jaap (NED)           SZEKELY Ferenc (HUN)  43950100.0
# 619       RATTALINO Jorge (ARG)           HASSOUNEH Awni (JOR)  43950100.0
# 620           FARAG Wagih (EGY)            BEREUTER Egon (AUT)  43950100.0
# 627          SHARP Philip (ENG)     KOMALEESWARAN Sankar (IND)  43950100.0
# 642          ALTRAIFI Ali (KSA)           VERGARA Hector (CAN)  43950500.0
# 644          GARCIA Dario (ARG)            OTERO Rodolfo (ARG)  97410100.0
# 664     COPELLI Cristiano (ITA)      STAGNOLI Alessandro (ITA)  97410100.0
# 683     CAMARGO Jose Luis (MEX)              LEAL Leonel (CRC)  97410100.0
# 686        DAGORNE Lionel (FRA)           TEXIER Vincent (FRA)  97410100.0
# 725         HERMANS Peter (BEL)           VROMANS Walter (BEL)    249722.0
# 737     BASUALTO Patricio (CHI)        MONDRIA Francisco (CHI)    249722.0
# 748           Darren CANN (ENG)        MULLARKEY Michael (ENG)    249722.0
# 758         FANDINO Pablo (URU)        ESPINOSA Mauricio (URU)    249717.0
# 768        ILYASOV Rafael (UZB)       KOCHKAROV Bakhadyr (KGZ)    249719.0
# 770        VERGARA Hector (CAN)        TORRENTERA Marvin (MEX)    249720.0
# 774       Renato FAVERANI (ITA)           Andrea STEFANI (ITA)    255931.0
# 789        ACHIK Redouane (MAR)        ETCHIALI Abdelhak (ALG)    255931.0
# 796     Sander VAN ROEKEL (NED)           Erwin ZEINSTRA (NED)    255931.0
# 802          DIAZ Eduardo (COL)        LESCANO Christian (ECU)    255931.0
# 806     KLASENIUS Mathias (SWE)          WARNMARK Daniel (SWE)    255931.0
# 810       MIRANDA Bertino (POR)               TRIGO Jose (POR)    255931.0
# 812       Renato FAVERANI (ITA)           Andrea STEFANI (ITA)    255931.0
# 826     TORRENTERA Marvin (MEX)          QUINTERO Marcos (MEX)    255955.0
# 848     TORRENTERA Marvin (MEX)          QUINTERO Marcos (MEX)    255955.0
#
#          MatchID Home Team Initials Away Team Initials
# 0         1096.0                FRA                MEX
# 10        1086.0                ARG                MEX
# 15        1088.0                ARG                USA
# 16        1101.0                URU                YUG
# 17        1087.0                URU                ARG
# 18        1104.0                AUT                FRA
# 19        1119.0                HUN                EGY
# 20        1133.0                SUI                NED
# 21        1102.0                SWE                ARG
# 22        1108.0                GER                BEL
# 24        1135.0                ITA                USA
# 26        1143.0                TCH                SUI
# 33        1105.0                GER                AUT
# 36        1173.0                HUN                INH
# 38        1156.0                CUB                ROU
# 40        1150.0                BRA                POL
# 43        1166.0                SUI                GER
# 46        1158.0                SWE                CUB
# 49        1176.0                HUN                SWE
# 51        1151.0                BRA                SWE
# 52        1174.0                ITA                HUN
# 56        1219.0                SWE                ITA
# 59        1225.0                YUG                MEX
# 66        1185.0                URU                BOL
# 68        1194.0                CHI                USA
# 70        1189.0                BRA                SWE
# 71        1186.0                BRA                ESP
# 72        1231.0                URU                SWE
# 77        1249.0                BRA                MEX
# 79        1283.0                FRG                TUR
# ..           ...                ...                ...
# 554       8761.0                ESP                BUL
# 565       8773.0                BRA                CHI
# 567       8775.0                NGA                DEN
# 573       8782.0                BRA                DEN
# 583   43950004.0                GER                KSA
# 595   43950016.0                USA                POR
# 613   43950034.0                SEN                URU
# 619   43950039.0                RSA                ESP
# 620   43950041.0                CRC                BRA
# 627   43950046.0                BEL                RUS
# 642   43950063.0                KOR                TUR
# 644   97410001.0                GER                CRC
# 664   97410021.0                ARG                SCG
# 683   97410038.0                CIV                SCG
# 686   97410043.0                JPN                BRA
# 725  300061458.0                ARG                KOR
# 737  300061487.0                POR                PRK
# 748  300061480.0                SVK                ITA
# 758  300061501.0                GER                ENG
# 768  300061512.0                URU                NED
# 770  300061510.0                URU                GER
# 774  300186510.0                ESP                NED
# 789  300186478.0                AUS                NED
# 796  300186514.0                SUI                FRA
# 802  300186495.0                KOR                ALG
# 806  300186472.0                CMR                BRA
# 810  300186457.0                JPN                COL
# 812  300186458.0                NGA                ARG
# 826  300186474.0                BRA                GER
# 848  300186474.0                BRA                GER
#
# [147 rows x 20 columns]

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column "Half-time Goals".

# %%
half_goals = df['Half-time Home Goals'] + df['Half-time Away Goals']
df['Half-time Goals'] = half_goals
df.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions       ...        Half-time Home Goals  Half-time Away Goals  \
# 0                      ...                         3.0                   0.0
# 1                      ...                         2.0                   0.0
# 2                      ...                         2.0                   0.0
# 3                      ...                         1.0                   0.0
# 4                      ...                         0.0                   0.0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2 RoundID  MatchID  Home Team Initials  \
# 0         REGO Gilberto (BRA)   201.0   1096.0                 FRA
# 1       WARNKEN Alberto (CHI)   201.0   1090.0                 USA
# 2         BALWAY Thomas (FRA)   201.0   1093.0                 YUG
# 3    MATEUCCI Francisco (URU)   201.0   1098.0                 ROU
# 4  RADULESCU Constantin (ROU)   201.0   1085.0                 ARG
#
#   Away Team Initials Half-time Goals
# 0                MEX             3.0
# 1                BEL             2.0
# 2                BRA             2.0
# 3                PER             1.0
# 4                FRA             0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
df.loc[df["Home Team Name"].str.contains('Korea'), "Home Team Name" ]
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-15-c928ce4a0a52> in <module>
# ----> 1 df.loc[df["Home Team Name"].str.contains('Korea'), "Home Team Name" ]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1025                     return section
#    1026                 # This is an elided recursive call to iloc/loc/etc'
# -> 1027                 return getattr(section, self.name)[new_key]
#    1028
#    1029         raise IndexingError('not applicable')
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1865             self._validate_key(key, axis)
#    1866             return self._get_slice_axis(key, axis=axis)
# -> 1867         elif com.is_bool_indexer(key):
#    1868             return self._getbool_axis(key, axis=axis)
#    1869         elif is_list_like_indexer(key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     105             if not lib.is_bool_array(key):
#     106                 if isna(key).any():
# --> 107                     raise ValueError('cannot index with vector containing '
#     108                                      'NA / NaN values')
#     109                 return False
#
# ValueError: cannot index with vector containing NA / NaN values

# %% [markdown]
# Imagine that for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
df.loc[df["Home Team Name"] == 'Korea Republic', "Home Team Name"] = "Korea"
df.loc[df["Home Team Name"] == 'Korea DPR', "Home Team Name"] = "Korea"
df.loc[df["Away Team Name"] == 'Korea Republic', "Away Team Name"] = "Korea"
df.loc[df["Away Team Name"] == 'Korea DPR', "Away Team Name"] = "Korea"
df.loc[df["Home Team Initials"] == 'KOR', 'Home Team Initials'] = "NSK"
df.loc[df["Home Team Initials"] == 'PRK', 'Home Team Initials'] = "NSK"
df.loc[df["Away Team Initials"] == 'KOR', "Away Team Initials"] = "NSK"
df.loc[df["Away Team Initials"] == 'PRK', "Away Team Initials"] = "NSK"

# %% [markdown]
# Make sure to verify your answer!

# %%
all_teams = df['Home Team Name'].unique()
all_teams
# Out:
# array(['France', 'USA', 'Yugoslavia', 'Romania', 'Argentina', 'Chile',
#        'Uruguay', 'Brazil', 'Paraguay', 'Austria', 'Hungary',
#        'Switzerland', 'Sweden', 'Germany', 'Spain', 'Italy',
#        'Czechoslovakia', 'Cuba', 'England', 'Germany FR', 'Turkey',
#        'Soviet Union', 'Northern Ireland', 'Mexico', 'Wales', 'Portugal',
#        'Korea', 'Peru', 'Belgium', 'Bulgaria', 'German DR', 'Zaire',
#        'Poland', 'Australia', 'Scotland', 'Netherlands', 'Haiti',
#        'Tunisia', 'Algeria', 'Honduras', 'Canada', 'Morocco', 'Iraq',
#        'Denmark', 'rn">United Arab Emirates', 'Costa Rica', 'Cameroon',
#        'rn">Republic of Ireland', 'Colombia', 'Norway', 'Nigeria',
#        'Saudi Arabia', 'Bolivia', 'Russia', 'Greece', 'Jamaica',
#        'South Africa', 'Japan', 'Croatia', 'China PR', 'Senegal',
#        'Slovenia', 'Ecuador', 'rn">Trinidad and Tobago',
#        'rn">Serbia and Montenegro', 'Angola', 'Czech Republic', 'Togo',
#        'Iran', "C�te d'Ivoire", 'Ghana', 'Ukraine', 'Serbia',
#        'New Zealand', 'Slovakia', 'IR Iran', 'rn">Bosnia and Herzegovina',
#        nan], dtype=object)
